# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import PIL
from glob import glob
from tensorflow.keras.layers.experimental.preprocessing import Rescaling
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization, Conv2D, MaxPooling2D

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %%
# !ls
# Out:
# gdrive	sample_data

# %%
# !ls "/content/gdrive/My Drive/Colab Notebooks/"

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/My Drive/Colab Notebooks/Train/")
data_dir_test = pathlib.Path('/content/gdrive/My Drive/Colab Notebooks/Test/')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='training',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir_train,
    labels='inferred',
    label_mode='categorical',
    class_names=None,
    color_mode='rgb',
    batch_size=32,
    image_size=(img_height, img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset='validation',
    interpolation='bilinear',
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

num=0
for dirpath, dirnames, filenames in os.walk(str(data_dir_train)):
    for filename in [f for f in filenames if f.endswith(".jpg")][:1]:
        img = PIL.Image.open(str(dirpath)+"/"+str(filename))
        plt.subplot(3,3,num+1)
        plt.title(str(dirpath).split('/')[-1])
        plt.axis('off')
        plt.imshow(img)
        num=num+1

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here
model=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ###Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 210s 764ms/step - loss: 2.5018 - accuracy: 0.2372 - val_loss: 1.9817 - val_accuracy: 0.3333
# Epoch 2/20
# 56/56 [==============================] - 3s 51ms/step - loss: 1.7676 - accuracy: 0.3717 - val_loss: 1.7203 - val_accuracy: 0.4049
# Epoch 3/20
# 56/56 [==============================] - 3s 51ms/step - loss: 1.5860 - accuracy: 0.4392 - val_loss: 1.5773 - val_accuracy: 0.4966
# Epoch 4/20
# 56/56 [==============================] - 3s 51ms/step - loss: 1.4658 - accuracy: 0.4944 - val_loss: 1.5456 - val_accuracy: 0.4944
# Epoch 5/20
# 56/56 [==============================] - 3s 51ms/step - loss: 1.4050 - accuracy: 0.5206 - val_loss: 1.4823 - val_accuracy: 0.5213
# Epoch 6/20
# 56/56 [==============================] - 3s 56ms/step - loss: 1.3337 - accuracy: 0.5285 - val_loss: 1.3923 - val_accuracy: 0.5347
# Epoch 7/20
# 56/56 [==============================] - 3s 52ms/step - loss: 1.2525 - accuracy: 0.5625 - val_loss: 1.4332 - val_accuracy: 0.5056
# Epoch 8/20
# 56/56 [==============================] - 3s 50ms/step - loss: 1.2138 - accuracy: 0.5770 - val_loss: 1.4233 - val_accuracy: 0.5190
# Epoch 9/20
# 56/56 [==============================] - 3s 53ms/step - loss: 1.0920 - accuracy: 0.6094 - val_loss: 1.3765 - val_accuracy: 0.5369
# Epoch 10/20
# 56/56 [==============================] - 3s 51ms/step - loss: 1.0481 - accuracy: 0.6306 - val_loss: 1.5087 - val_accuracy: 0.5213
# Epoch 11/20
# 56/56 [==============================] - 3s 50ms/step - loss: 1.0209 - accuracy: 0.6311 - val_loss: 1.4543 - val_accuracy: 0.5056
# Epoch 12/20
# 56/56 [==============================] - 3s 50ms/step - loss: 0.9068 - accuracy: 0.6842 - val_loss: 1.4559 - val_accuracy: 0.5235
# Epoch 13/20
# 56/56 [==============================] - 3s 53ms/step - loss: 0.8511 - accuracy: 0.7003 - val_loss: 1.4190 - val_accuracy: 0.5459
# Epoch 14/20
# 56/56 [==============================] - 3s 52ms/step - loss: 0.7913 - accuracy: 0.7003 - val_loss: 1.5159 - val_accuracy: 0.5302
# Epoch 15/20
# 56/56 [==============================] - 3s 50ms/step - loss: 0.6840 - accuracy: 0.7539 - val_loss: 1.4486 - val_accuracy: 0.5414
# Epoch 16/20
# 56/56 [==============================] - 3s 50ms/step - loss: 0.6344 - accuracy: 0.7656 - val_loss: 1.6444 - val_accuracy: 0.5302
# Epoch 17/20
# 56/56 [==============================] - 3s 51ms/step - loss: 0.5951 - accuracy: 0.7796 - val_loss: 1.7836 - val_accuracy: 0.5459
# Epoch 18/20
# 56/56 [==============================] - 3s 56ms/step - loss: 0.5586 - accuracy: 0.7997 - val_loss: 1.6859 - val_accuracy: 0.5347
# Epoch 19/20
# 56/56 [==============================] - 3s 50ms/step - loss: 0.5128 - accuracy: 0.8142 - val_loss: 1.7467 - val_accuracy: 0.5593
# Epoch 20/20
# 56/56 [==============================] - 3s 50ms/step - loss: 0.4559 - accuracy: 0.8276 - val_loss: 1.6496 - val_accuracy: 0.5436

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_2 (Conv2D)           (None, 180, 180, 32)      896
#
#  max_pooling2d_2 (MaxPoolin  (None, 90, 90, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 90, 90, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 90, 90, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 45, 45, 64)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 45, 45, 64)        0
#
#  flatten_1 (Flatten)         (None, 129600)            0
#
#  dense_2 (Dense)             (None, 128)               16588928
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 16609481 (63.36 MB)
# Trainable params: 16609481 (63.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ## ***Findings/Observations***
# 1. The accuracy of the model for the Training data set is at ~85%. But the Validation accuracy is not in par with the training accuracy.
# It is only at ~54%.
# 2. The validation loss as observed is very high. This can also indicate that the model might get overfit.
# 3. We could add some Dropout layers and remove the BatchNormalization layers.
# And by adding a few more layers, we could improve the accuracy by trying to extract more features.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# Your code goes here

data_augmentation=tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here

image, label = next(iter(train_ds))
image=np.array(image,np.int32)
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(3, 3, i + 1)
  augmented_image1=np.array(augmented_image[0],np.int32)
  plt.imshow((augmented_image1))
  plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings


model_augmented=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),

    data_augmentation,

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    Conv2D(32,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Conv2D(128,(3,3),activation='relu',padding='same'),
    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.7),

    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])

# %% [markdown]
# ### Compiling the model

# %%
model_augmented.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics='accuracy')

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs

epochs = 20
history = model_augmented.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 13s 133ms/step - loss: 2.2288 - accuracy: 0.1897 - val_loss: 2.0715 - val_accuracy: 0.2058
# Epoch 2/20
# 56/56 [==============================] - 6s 112ms/step - loss: 2.0391 - accuracy: 0.2087 - val_loss: 2.0266 - val_accuracy: 0.1924
# Epoch 3/20
# 56/56 [==============================] - 6s 113ms/step - loss: 2.0236 - accuracy: 0.1998 - val_loss: 2.0292 - val_accuracy: 0.1924
# Epoch 4/20
# 56/56 [==============================] - 6s 114ms/step - loss: 2.0229 - accuracy: 0.1925 - val_loss: 2.0163 - val_accuracy: 0.1924
# Epoch 5/20
# 56/56 [==============================] - 7s 124ms/step - loss: 1.9996 - accuracy: 0.2204 - val_loss: 1.9183 - val_accuracy: 0.3199
# Epoch 6/20
# 56/56 [==============================] - 7s 120ms/step - loss: 1.8882 - accuracy: 0.2812 - val_loss: 1.8962 - val_accuracy: 0.3087
# Epoch 7/20
# 56/56 [==============================] - 7s 121ms/step - loss: 1.8365 - accuracy: 0.3025 - val_loss: 1.7648 - val_accuracy: 0.3445
# Epoch 8/20
# 56/56 [==============================] - 7s 121ms/step - loss: 1.8360 - accuracy: 0.3058 - val_loss: 1.7029 - val_accuracy: 0.4049
# Epoch 9/20
# 56/56 [==============================] - 7s 117ms/step - loss: 1.7668 - accuracy: 0.3460 - val_loss: 1.6920 - val_accuracy: 0.3960
# Epoch 10/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.7037 - accuracy: 0.3633 - val_loss: 1.6666 - val_accuracy: 0.4072
# Epoch 11/20
# 56/56 [==============================] - 6s 115ms/step - loss: 1.7901 - accuracy: 0.3415 - val_loss: 1.8330 - val_accuracy: 0.3356
# Epoch 12/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.6612 - accuracy: 0.4057 - val_loss: 1.8985 - val_accuracy: 0.2886
# Epoch 13/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.6816 - accuracy: 0.3884 - val_loss: 1.7185 - val_accuracy: 0.3781
# Epoch 14/20
# 56/56 [==============================] - 6s 113ms/step - loss: 1.6221 - accuracy: 0.3968 - val_loss: 1.6050 - val_accuracy: 0.4430
# Epoch 15/20
# 56/56 [==============================] - 7s 119ms/step - loss: 1.6120 - accuracy: 0.4152 - val_loss: 1.6672 - val_accuracy: 0.4340
# Epoch 16/20
# 56/56 [==============================] - 6s 114ms/step - loss: 1.5967 - accuracy: 0.3962 - val_loss: 1.7589 - val_accuracy: 0.3557
# Epoch 17/20
# 56/56 [==============================] - 6s 115ms/step - loss: 1.6533 - accuracy: 0.3878 - val_loss: 1.5951 - val_accuracy: 0.4340
# Epoch 18/20
# 56/56 [==============================] - 7s 118ms/step - loss: 1.5760 - accuracy: 0.4241 - val_loss: 1.6172 - val_accuracy: 0.4027
# Epoch 19/20
# 56/56 [==============================] - 7s 121ms/step - loss: 1.5931 - accuracy: 0.4018 - val_loss: 1.5773 - val_accuracy: 0.4251
# Epoch 20/20
# 56/56 [==============================] - 7s 120ms/step - loss: 1.5831 - accuracy: 0.4297 - val_loss: 1.6675 - val_accuracy: 0.4407

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# # ***Findings/Observations***
# 1. The accuracy for the train set is ~43%
# 2. The accuracy for the Validation set is also at ~44%.
# 3. Though the model accuracy for train and validation data had decreased when compared to the first model, as the accuracy scores are close to each other, this model is better than the first model.
# 4. Hence, we can say that Data Augmentation has definitely improved the model performance.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

for i in class_names:
    directory ='gdrive/My Drive/Colab Notebooks/Train/'+i+'/'
    class_directory = pathlib.Path(directory)
    length=len(list(class_directory.glob('*.jpg')))
    print(f'{i} has {length} samples.')
# Out:
# actinic keratosis has 114 samples.
# basal cell carcinoma has 376 samples.
# dermatofibroma has 95 samples.
# melanoma has 438 samples.
# nevus has 357 samples.
# pigmented benign keratosis has 462 samples.
# seborrheic keratosis has 77 samples.
# squamous cell carcinoma has 181 samples.
# vascular lesion has 139 samples.

# %% [markdown]
# #### **Todo:** Write your findings here:
# ***There is a huge different in the number of samples for each class and the data is clearly imbalanced.***
# #### - Which class has the least number of samples?
# ***Ans: 'seborrheic keratosis' has got the least number of samples.***
# #### - Which classes dominate the data in terms proportionate number of samples?
# ***Ans: 'pigmented benign keratosis' has the highest number of samples i.e, 462, followed by 'melanoma' which has 438 samples.***

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.23.5)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset="gdrive/My Drive/Colab Notebooks/Train/"
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7DE2B031D6C0>: 100%|██████████| 500/500 [00:19<00:00, 26.24 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/basal cell carcinoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7DE2B01A7EB0>: 100%|██████████| 500/500 [00:17<00:00, 29.06 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7DE2B02D1C00>: 100%|██████████| 500/500 [00:17<00:00, 29.07 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7DE2CEFD6800>: 100%|██████████| 500/500 [01:34<00:00,  5.31 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=2048x1536 at 0x7DE2CEFD6DD0>: 100%|██████████| 500/500 [01:07<00:00,  7.43 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/pigmented benign keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7DE2B02D0730>: 100%|██████████| 500/500 [00:20<00:00, 23.94 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7DE2CC1F1450>: 100%|██████████| 500/500 [00:40<00:00, 12.27 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7DE2CEFD4DF0>: 100%|██████████| 500/500 [00:18<00:00, 26.51 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to gdrive/My Drive/Colab Notebooks/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7DE2CC1F1450>: 100%|██████████| 500/500 [00:19<00:00, 26.04 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
for i in class_names:
    directory ='gdrive/My Drive/Colab Notebooks/Train/'+i+'/'
    directory_out ='gdrive/My Drive/Colab Notebooks/Train/'+i+'/output/'
    class_directory = pathlib.Path(directory)
    class_directory_out = pathlib.Path(directory_out)
    length=len(list(class_directory.glob('*.jpg')))
    length_out=len(list(class_directory_out.glob('*.jpg')))
    length_tot=length+length_out
    print(f'{i} has {length_tot} samples.')
# Out:
# actinic keratosis has 614 samples.
# basal cell carcinoma has 876 samples.
# dermatofibroma has 595 samples.
# melanoma has 938 samples.
# nevus has 857 samples.
# pigmented benign keratosis has 962 samples.
# seborrheic keratosis has 577 samples.
# squamous cell carcinoma has 681 samples.
# vascular lesion has 639 samples.

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  label_mode='categorical',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

model_final=Sequential([
    tf.keras.layers.experimental.preprocessing.Rescaling(scale=1./255., offset=0.0,),

    Conv2D(32,(3,3),input_shape=(img_height,img_width,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Conv2D(64,(3,3),activation='relu',padding='same'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.1),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.25),
    Dense(9, activation='softmax')
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model_final.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics='accuracy')

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30

history = model_final.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 51s 288ms/step - loss: 2.1530 - accuracy: 0.2876 - val_loss: 1.7378 - val_accuracy: 0.3667
# Epoch 2/30
# 169/169 [==============================] - 40s 230ms/step - loss: 1.4812 - accuracy: 0.4457 - val_loss: 1.4039 - val_accuracy: 0.4803
# Epoch 3/30
# 169/169 [==============================] - 43s 246ms/step - loss: 1.2846 - accuracy: 0.5174 - val_loss: 1.1564 - val_accuracy: 0.5702
# Epoch 4/30
# 169/169 [==============================] - 37s 211ms/step - loss: 1.1122 - accuracy: 0.5933 - val_loss: 1.1334 - val_accuracy: 0.5902
# Epoch 5/30
# 169/169 [==============================] - 40s 228ms/step - loss: 1.0060 - accuracy: 0.6365 - val_loss: 1.0729 - val_accuracy: 0.6362
# Epoch 6/30
# 169/169 [==============================] - 40s 222ms/step - loss: 0.8992 - accuracy: 0.6788 - val_loss: 0.9530 - val_accuracy: 0.6667
# Epoch 7/30
# 169/169 [==============================] - 38s 217ms/step - loss: 0.7675 - accuracy: 0.7227 - val_loss: 0.9503 - val_accuracy: 0.6808
# Epoch 8/30
# 169/169 [==============================] - 37s 214ms/step - loss: 0.7038 - accuracy: 0.7474 - val_loss: 0.8846 - val_accuracy: 0.7142
# Epoch 9/30
# 169/169 [==============================] - 41s 238ms/step - loss: 0.5919 - accuracy: 0.7873 - val_loss: 0.9050 - val_accuracy: 0.7134
# Epoch 10/30
# 169/169 [==============================] - 37s 215ms/step - loss: 0.5472 - accuracy: 0.8058 - val_loss: 0.8336 - val_accuracy: 0.7365
# Epoch 11/30
# 169/169 [==============================] - 36s 209ms/step - loss: 0.5527 - accuracy: 0.8079 - val_loss: 0.9601 - val_accuracy: 0.7134
# Epoch 12/30
# 169/169 [==============================] - 36s 208ms/step - loss: 0.4323 - accuracy: 0.8470 - val_loss: 0.7593 - val_accuracy: 0.7580
# Epoch 13/30
# 169/169 [==============================] - 34s 198ms/step - loss: 0.3963 - accuracy: 0.8579 - val_loss: 0.7999 - val_accuracy: 0.7587
# Epoch 14/30
# 169/169 [==============================] - 36s 202ms/step - loss: 0.3745 - accuracy: 0.8661 - val_loss: 0.7761 - val_accuracy: 0.7877
# Epoch 15/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.3280 - accuracy: 0.8833 - val_loss: 0.7916 - val_accuracy: 0.7728
# Epoch 16/30
# 169/169 [==============================] - 36s 203ms/step - loss: 0.3241 - accuracy: 0.8828 - val_loss: 0.8479 - val_accuracy: 0.7877
# Epoch 17/30
# 169/169 [==============================] - 39s 226ms/step - loss: 0.3029 - accuracy: 0.8885 - val_loss: 0.7916 - val_accuracy: 0.7936
# Epoch 18/30
# 169/169 [==============================] - 35s 200ms/step - loss: 0.2762 - accuracy: 0.8976 - val_loss: 0.8348 - val_accuracy: 0.7906
# Epoch 19/30
# 169/169 [==============================] - 35s 199ms/step - loss: 0.2418 - accuracy: 0.9071 - val_loss: 0.9354 - val_accuracy: 0.7661
# Epoch 20/30
# 169/169 [==============================] - 35s 201ms/step - loss: 0.2426 - accuracy: 0.9089 - val_loss: 0.9176 - val_accuracy: 0.7795
# Epoch 21/30
# 169/169 [==============================] - 35s 198ms/step - loss: 0.2362 - accuracy: 0.9115 - val_loss: 0.9041 - val_accuracy: 0.7884
# Epoch 22/30
# 169/169 [==============================] - 39s 225ms/step - loss: 0.2230 - accuracy: 0.9177 - val_loss: 0.8752 - val_accuracy: 0.7988
# Epoch 23/30
# 169/169 [==============================] - 34s 198ms/step - loss: 0.2036 - accuracy: 0.9258 - val_loss: 0.8472 - val_accuracy: 0.8129
# Epoch 24/30
# 169/169 [==============================] - 36s 206ms/step - loss: 0.2328 - accuracy: 0.9130 - val_loss: 0.9329 - val_accuracy: 0.7699
# Epoch 25/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.2011 - accuracy: 0.9219 - val_loss: 0.9026 - val_accuracy: 0.7892
# Epoch 26/30
# 169/169 [==============================] - 36s 205ms/step - loss: 0.2377 - accuracy: 0.9156 - val_loss: 1.4534 - val_accuracy: 0.6949
# Epoch 27/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.2428 - accuracy: 0.9117 - val_loss: 1.0260 - val_accuracy: 0.7691
# Epoch 28/30
# 169/169 [==============================] - 36s 204ms/step - loss: 0.1923 - accuracy: 0.9299 - val_loss: 0.9266 - val_accuracy: 0.7884
# Epoch 29/30
# 169/169 [==============================] - 34s 197ms/step - loss: 0.1959 - accuracy: 0.9267 - val_loss: 0.9616 - val_accuracy: 0.8107
# Epoch 30/30
# 169/169 [==============================] - 34s 196ms/step - loss: 0.1654 - accuracy: 0.9340 - val_loss: 1.0085 - val_accuracy: 0.8070

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# ## ***Findings/Observations:***
# #### 1. The training accuracy seems to be nearly ~93%.
# #### 2. The validation accuracy is nearly ~80%.
# #### 3. Though the model accuracy has improved, the augmentation and class rebalance has helped treat the overfitting.
